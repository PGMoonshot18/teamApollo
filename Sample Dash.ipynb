# %%
import pandas as pd
import plotly
import requests
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from sympy import *
# %matplotlib notebook
import datetime

# %%
url = 'https://raw.githubusercontent.com/aescay/moonshot/master/Desktop/Data%20Science/P%26G%20Moonshot/Test.csv'
url_baseline = 'https://raw.githubusercontent.com/aescay/moonshot/master/water.txt'
url_nasoap = 'https://raw.githubusercontent.com/aescay/moonshot/master/nosoap.txt'
url_soap = 'https://raw.githubusercontent.com/aescay/moonshot/master/soap.txt'

# %%
pd.read_csv(url, error_bad_lines=False)
# Out:
#           Time       Count
# 0     0.095604  718.629358
# 1     0.305881  194.818668
# 2     0.748700  181.624142
# 3     0.215318  436.352883
# 4     0.710197  984.508416
# 5     0.517416  354.733544
# 6     0.883517  545.127498
# 7     0.583121  466.813824
# 8     0.025584  921.438820
# 9     0.668207  759.556077
# 10    0.185469  151.745696
# 11    0.635519   97.482076
# 12    0.443117  389.690799
# 13    0.135825  650.647341
# 14    0.545078  660.240412
# 15    0.134838  617.835576
# 16    0.555922   26.546832
# 17    0.201548  778.719801
# 18    0.049344  504.699882
# 19    0.976768  946.248938
# 20    0.368361  410.973239
# 21    0.119098  730.393669
# 22    0.640155  620.905737
# 23    0.824902  377.698522
# 24    0.455396  149.543211
# 25    0.694471   59.972848
# 26    0.452732   15.316287
# 27    0.250050  671.949654
# 28    0.929134  195.794664
# 29    0.835112  459.952594
# ...        ...         ...
# 1340  0.843984  385.783151
# 1341  0.784181  396.839850
# ...

# %%
water = pd.read_table(url_baseline, header = None, names = ['water'])
no_soap = pd.read_table(url_nasoap, header = None, names = ['no_soap'])
soap = pd.read_table(url_soap, header = None, names = ['soap'])

# %%
print(water)
print(no_soap)
print(soap)
# Out:
#    water
# 0    255
# 1    252
# 2    252
# 3    247
# 4    244
# 5    247
# 6    245
# 7    248
# 8    250
# 9    247
#    no_soap
# 0      236
# 1      229
# 2      224
# 3      228
# 4      219
# 5      225
# 6      235
# 7      242
# 8      254
# 9      256
#    soap
# 0   209
# 1   229
# 2   235
# 3   236
# 4   232
# 5   239
# 6   237
# 7   233
# 8   235
# 9   232

# %%
print(np.std(water))
print(np.std(no_soap))
print(np.std(soap))
# Out:
# water    3.287856
# dtype: float64
# no_soap    11.889491
# dtype: float64
# soap    8.038035
# dtype: float64

# %%
print(np.mean(water))
print(np.mean(no_soap))
print(np.mean(soap))
# Out:
# water    248.7
# dtype: float64
# no_soap    234.8
# dtype: float64
# soap    231.7
# dtype: float64

# %%
stats.ttest_ind(no_soap,soap)
# Out:
# Ttest_indResult(statistic=array([ 0.64800889]), pvalue=array([ 0.52515967]))

# %%
trial_1 = 'https://raw.githubusercontent.com/aescay/moonshot/master/water.txt'
trial_2 = 'https://raw.githubusercontent.com/aescay/moonshot/master/trial2.txt'
trial_3 = 'https://raw.githubusercontent.com/aescay/moonshot/master/trial3.txt'
idealistic1 = 'https://raw.githubusercontent.com/aescay/moonshot/master/idealistic1.txt'
idealistic2 = 'https://raw.githubusercontent.com/aescay/moonshot/master/idealistic2.txt'

# %%
collated = [trial_1, trial_2, trial_3, idealistic1, idealistic2]

df_collated = pd.DataFrame()
blah = []

for i in collated:
    temp = str(i).split('/')[-1]
    blah.append(temp)
    df_collated[i] = pd.read_table(i, header = None, names = [i])

# %%
df_collated.columns = blah

# %%
df_collated
# Out:
#     water.txt  trial2.txt  trial3.txt  idealistic1.txt  idealistic2.txt
# 0         160         261           1            154.0            112.0
# 1         160         261         701            163.0            106.0
# 2         182         265         701            163.0            106.0
# 3         180         259         701            167.0            105.0
# 4         194         249         701            177.0            102.0
# 5         246         259         701            263.0            101.0
# 6         249         252         701            258.0            100.0
# 7         206         267         701            204.0            100.0
# 8         276         269         701            259.0             98.0
# 9         382         251         701            284.0             97.0
# 10        190         340         701              NaN              NaN
# 11        215         455         701              NaN              NaN
# ...

# %%
type(i)
# Out:
# str

# %%
plt.figure(figsize=(10,6))
plt.plot(df_collated.index,df_collated['water.txt'].diff(), '-', color = 'red', alpha = 0.5)
# plt.plot(df_collated.index,df_collated['water.txt'], '-', color = 'blue', alpha = 0.5)
# plt.plot(df_collated.index,df_collated['trial3.txt'].diff(), '-', color = 'green', alpha = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
df_collated['water.txt'].diff()
# Out:
# 0       NaN
# 1       0.0
# 2      22.0
# 3      -2.0
# 4      14.0
# 5      52.0
# 6       3.0
# 7     -43.0
# 8      70.0
# 9     106.0
# 10   -192.0
# 11     25.0
# 12      4.0
# 13     21.0
# 14    194.0
# 15     20.0
# 16   -151.0
# 17    -84.0
# 18    -26.0
# 19     13.0
# 20      7.0
# 21      5.0
# 22     -8.0
# 23     -3.0
# 24      1.0
# 25      0.0
# 26     -8.0
# 27     11.0
# 28     45.0
# 29    -72.0
# Name: water.txt, dtype: float64

# %%
trial_1 = 'https://raw.githubusercontent.com/aescay/moonshot/master/trial1.txt'
trial_2 = 'https://raw.githubusercontent.com/aescay/moonshot/master/trial2.txt'
trial_3 = 'https://raw.githubusercontent.com/aescay/moonshot/master/trial3.txt'

# %%
collated = [trial_1, trial_2, trial_3]

df_collated = pd.DataFrame()
blah = []

for i in collated:
    temp = str(i).split('/')[-1]
    blah.append(temp)
    df_collated[i] = pd.read_table(i, header = None, names = [i])
    
df_collated.columns = blah

# %%
plt.figure(figsize=(10,6))
plt.plot(df_collated.index,df_collated['trial1.txt'], '-', color = 'red', alpha = 0.5)
plt.plot(df_collated.index,df_collated['trial2.txt'], '-', color = 'blue', alpha = 0.5)
plt.plot(df_collated.index,df_collated['trial3.txt'], '-', color = 'green', alpha = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
times = pd.read_csv('times2.csv',index_col=0, skip_blank_lines=True)[:-1]

# %%
water_only = pd.DataFrame()

df_sorted = pd.DataFrame()

for x in list(times.index.values):
    y = pd.Series()
    for i in list(df_collated.columns.get_values()):
        y[i] = df_collated[i][int(times[i][x].split(':')[0])+5:int(times[i][x].split(':')[1])-5]
    df_sorted[x] = y

# %%
int(times[i][x].split(':')[0])+5
# Out:
# 5

# %%
for i in df_sorted.columns.get_values():
    for x in df_sorted.index.values:
        print(x,i,min(df_sorted[i][x]))
# Out:
# trial1.txt Water 226
# trial2.txt Water 223
# trial3.txt Water 184
# trial1.txt Hand 209
# trial2.txt Hand 231
# trial3.txt Hand 243
# trial1.txt Remove1 255
# trial2.txt Remove1 278
# trial3.txt Remove1 303
# trial1.txt Soap 117
# trial2.txt Soap 112
# trial3.txt Soap 98

# %% [markdown]
# list(df_sorted.index.values())

# %%
df_collated['trial2.txt'][int(times['trial2.txt']['Remove1'].split(':')[0]):int(times['trial2.txt']['Remove1'].split(':')[1])]
# Out:
# Series([], Name: trial2.txt, dtype: int64)

# %%
int(times['trial2.txt']['Remove1'].split(':')[0]
# Out:
#   File "<ipython-input-269-5ae57613b627>", line 1
#     int(times['trial2.txt']['Remove1'].split(':')[0]
#                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
times['trial2.txt']['Remove1']
# Out:
# '312:285'

# %%
plotly.tools.set_credentials_file(username='aescay', api_key='J2pYNjN02ATxc2EejGps')

# %%
plotly.tools.set_config_file(world_readable=True,
                             sharing='public')

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace0 = Scatter(
    x=[1, 2, 3, 4],
    y=[10, 15, 13, 17]
)
trace1 = Scatter(
    x=[1, 2, 3, 4],
    y=[16, 5, 11, 9]
)
data = Data([trace0, trace1])

py.plot(data, filename = 'basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~aescay/0 or inside your plot.ly account where it is named 'basic-line'
# 'https://plot.ly/~aescay/0'

# %%
import plotly.graph_objs as go
import plotly.plotly as py

import numpy as np

colorscale = [[0, '#FAEE1C'], [0.33, '#F3558E'], [0.66, '#9C1DE7'], [1, '#581B98']]
trace1 = go.Scatter(
    y = np.random.randn(500),
    mode='markers',
    marker=dict(
        size='16',
        color = np.random.randn(500),
        colorscale=colorscale,
        showscale=True
    )
)
data = [trace1]
url_1 = py.plot(data, filename='scatter-for-dashboard', auto_open=False)
py.iplot(data, filename='scatter-for-dashboard')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aescay/2.embed" height="525px" width="100%"></iframe>

# %%
df = pd.read_csv('Final.csv')

# %%
now = datetime.datetime.now()

# %%
df.Date = pd.to_datetime(df.Date)
df.Date = df[df.Date < now]

# %%
trace = go.Scatter(
    x = df.Date,
    y = df['Number/Day'],
    line = dict(color = '#7D5CF7')
    
)

data = [trace]

py.iplot(data, filename='basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~aescay/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aescay/0.embed" height="525px" width="100%"></iframe>

# %%
labels = ['With Soap', "No Soap"]
values = [df["Percent with Soap wrt Time"][-1:], 1-df["Percent with Soap wrt Time"][-1:]]
trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename='basic_pie_chart')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aescay/4.embed" height="525px" width="100%"></iframe>

# %%
trace = go.Scatter(
    x = df.Date,
    y = df['Total Time (s)'],
    line = dict(color = '#7D5CF7')
    
)

data = [trace]


py.iplot(data, filename='time-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aescay/7.embed" height="525px" width="100%"></iframe>

# %%
labels = ['With Soap', "No Soap"]
values = [df["Percent with Soap wrt Number"][-1:], 1-df["Percent with Soap wrt Number"][-1:]]
trace = go.Pie(labels=labels, values=values)

py.iplot([trace], filename='basic_pie_chart_time')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aescay/9.embed" height="525px" width="100%"></iframe>

# %%
trace = go.Scatter(
    x = df.Date,
    y = df['Average time per handwash'],
    line = dict(color = '#7D5CF7')
    
)

data = [trace]


py.iplot(data, filename='ave-time')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aescay/11.embed" height="525px" width="100%"></iframe>

# %%
df
# Out:
#                      Date  Number/Day  Percent with Soap wrt Number  \
# 0     2016-01-01 00:00:00        7130                      0.888973
# 1     2016-01-02 00:00:00         556                      0.604517
# 2     2016-01-03 00:00:00         379                      0.702911
# 3     2016-01-04 00:00:00        6359                      0.373441
# 4     2016-01-05 00:00:00        4626                      0.541356
# 5     2016-01-06 00:00:00        3968                      0.859140
# 6     2016-01-07 00:00:00        4703                      0.339803
# 7     2016-01-08 00:00:00        4514                      0.700938
# 8     2016-01-09 00:00:00         291                      0.461494
# 9     2016-01-10 00:00:00         314                      0.721298
# 10    2016-01-11 00:00:00        4790                      0.631050
# 11    2016-01-12 00:00:00        3572                      0.576919
# 12    2016-01-13 00:00:00        7302                      0.504654
# ...
